# %%
# import the required modules
import pandas as pd
import numpy as np
pd.set_option("display.max_columns",None)

# %%
# load the csv file
df=pd.read_csv("E:/Project/Salaries.csv")
print(df)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
# Q1. Display Top 10 Rows of The Dataset
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %%
# Q2. Check Last 10 Rows of The Dataset
df.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle  BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant      0.0
# 148645  148646  Carolyn A Wilson     Human Services Technician      0.0
# 148646  148647      Not provided                  Not provided      NaN
# 148647  148648    Joann Anderson   Communications Dispatcher 2      0.0
# 148648  148649       Leon Walker                     Custodian      0.0
# 148649  148650     Roy I Tillery                     Custodian      0.0
# 148650  148651      Not provided                  Not provided      NaN
# 148651  148652      Not provided                  Not provided      NaN
# 148652  148653      Not provided                  Not provided      NaN
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148644          0.0      0.00       0.0      0.00              0.00  2014
# ...

# %%
# Q3. Find Shape of Our Dataset (Number of Rows And Number of Columns)
df.shape
# Out:
# (148654, 13)

# %%
# Q4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And  Memory Requirement
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
# Q5. Check Null Values In The Dataset
df.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %%
# OR 
# # Q5. Check Null Values In The Dataset
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %%
#Q6. Drop ID, Notes, Agency, and Status Columns
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df.drop(columns=['Id','Notes','Agency','Status'])
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
df.drop(['Id','Notes','Agency','Status'],axis=1,inplace=True)

# %%
df
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %%
# Q7. Get Overall Statistics About The Dataframe
df.dtypes
# Out:
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# dtype: object

# %%
df.describe()
# Out:
#              BasePay    OvertimePay       OtherPay       Benefits  \
# count  148045.000000  148650.000000  148650.000000  112491.000000
# mean    66325.448840    5066.059886    3648.767297   25007.893151
# std     42764.635495   11454.380559    8056.601866   15402.215858
# min      -166.010000      -0.010000   -7058.590000     -33.890000
# 25%     33588.200000       0.000000       0.000000   11535.395000
# 50%     65007.450000       0.000000     811.270000   28628.620000
# 75%     94691.050000    4658.175000    4236.065000   35566.855000
# max    319275.010000  245131.880000  400184.250000   96570.660000
#
#             TotalPay  TotalPayBenefits           Year
# count  148654.000000     148654.000000  148654.000000
# mean    74768.321972      93692.554811    2012.522643
# std     50517.005274      62793.533483       1.117538
# min      -618.130000       -618.130000    2011.000000
# 25%     36168.995000      44065.650000    2012.000000
# ...

# %%
df.describe(include="all")
# Out:
#        EmployeeName          JobTitle        BasePay    OvertimePay  \
# count        148654            148654  148045.000000  148650.000000
# unique       110811              2159            NaN            NaN
# top       Kevin Lee  Transit Operator            NaN            NaN
# freq             13              7036            NaN            NaN
# mean            NaN               NaN   66325.448840    5066.059886
# std             NaN               NaN   42764.635495   11454.380559
# min             NaN               NaN    -166.010000      -0.010000
# 25%             NaN               NaN   33588.200000       0.000000
# 50%             NaN               NaN   65007.450000       0.000000
# 75%             NaN               NaN   94691.050000    4658.175000
# max             NaN               NaN  319275.010000  245131.880000
#
#              OtherPay       Benefits       TotalPay  TotalPayBenefits  \
# count   148650.000000  112491.000000  148654.000000     148654.000000
# ...

# %%
# Q8. Find Occurrence of The Top 5 Employee Names 
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
df['EmployeeName'].value_counts()
# Out:
# EmployeeName
# Kevin Lee                   13
# Richard Lee                 11
# Steven Lee                  11
# William Wong                11
# Stanley Lee                  9
#                             ..
# Jeffrey Skover               1
# Ken Dever                    1
# Kevin Whitfield              1
# Granville McCollough III     1
# Joe Lopez                    1
# Name: count, Length: 110811, dtype: int64

# %%
df['EmployeeName'].value_counts().head()
# Out:
# EmployeeName
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: count, dtype: int64

# %%
# Q9. Find The Number of Unique Job Titles
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
df['JobTitle']
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object

# %%
df['JobTitle'].nunique()
# Out:
# 2159

# %%
len(df['JobTitle'].unique())
# Out:
# 2159

# %%
df['JobTitle'].unique().size
# Out:
# 2159

# %%
print("Number of Unique Job Titles : ",df['JobTitle'].nunique())
# Out:
# Number of Unique Job Titles :  2159

# %%
# importing the module
import numpy as np
import pandas as pd
pd.set_option("display.max_columns",None)

# %%
# load the csv file
df=pd.read_csv("E:/Project/Salaries.csv")
print(df)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
# Q10. Total Number of Job Titles Contain Captain
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df['JobTitle']
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object

# %%
df['JobTitle']=="Captain"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: JobTitle, Length: 148654, dtype: bool

# %%
df[df["JobTitle"]=="Captain"]
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Notes, Agency, Status]
# Index: []

# %%
df['JobTitle'].str.contains("Captain")
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: JobTitle, Length: 148654, dtype: bool

# %%
df[df['JobTitle'].str.contains("Captain")]
# Out:
#             Id        EmployeeName                   JobTitle    BasePay  \
# 36167    36168       John Goldberg                  Captain 3  104404.00
# 36180    36181    Michael Rolovich  Captain, Fire Suppression  145659.03
# 36184    36185       Darryl Hunter  Captain, Fire Suppression  145659.03
# 36186    36187      Michael Delane  Captain, Fire Suppression  147069.71
# 36189    36190      Philip Stevens  Captain, Fire Suppression  124573.50
# ...        ...                 ...                        ...        ...
# 116604  116605   Gregory L Stewart  Captain, Fire Suppression   73355.21
# 120867  120868     Michael J Moran                  Captain 3    7660.00
# 122361  122362  Michael V Rolovich  Captain, Fire Suppression       0.00
# 126588  126589    Stephen M Tittel                  Captain 3   68491.89
# 132232  132233     Jeanne M Seyler  Captain, Fire Suppression   61039.43
#
#         OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# ...

# %%
df[df['JobTitle'].str.contains("Captain")].shape[0]
# Out:
# 411

# %%
# Theire are some chance may be theire of  small letter of C in Captain word
df['JobTitle'].str.contains("Captain",case=False)
# Out:
# 0         False
# 1          True
# 2          True
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: JobTitle, Length: 148654, dtype: bool

# %%
df[df['JobTitle'].str.contains("Captain",case=False)]
# Out:
#             Id        EmployeeName                               JobTitle  \
# 1            2        GARY JIMENEZ        CAPTAIN III (POLICE DEPARTMENT)
# 2            3      ALBERT PARDINI        CAPTAIN III (POLICE DEPARTMENT)
# 11          12    PATRICIA JACKSON        CAPTAIN III (POLICE DEPARTMENT)
# 17          18      SEBASTIAN WONG  CAPTAIN, EMERGENCYCY MEDICAL SERVICES
# 22          23       GEORGE GARCIA              CAPTAIN, FIRE SUPPRESSION
# ...        ...                 ...                                    ...
# 116604  116605   Gregory L Stewart              Captain, Fire Suppression
# 120867  120868     Michael J Moran                              Captain 3
# 122361  122362  Michael V Rolovich              Captain, Fire Suppression
# 126588  126589    Stephen M Tittel                              Captain 3
# 132232  132233     Jeanne M Seyler              Captain, Fire Suppression
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %%
df[df['JobTitle'].str.contains("Captain",case=False)].shape[0]
# Out:
# 552

# %%
df[df['JobTitle'].str.contains("Captain",case=False)].count()
# Out:
# Id                  552
# EmployeeName        552
# JobTitle            552
# BasePay             551
# OvertimePay         552
# OtherPay            552
# Benefits            411
# TotalPay            552
# TotalPayBenefits    552
# Year                552
# Notes                 0
# Agency              552
# Status                0
# dtype: int64

# %%
df[df['JobTitle'].str.contains("Captain",case=False)].count()['JobTitle']
# Out:
# 552

# %%
# Q10. Total Number of Job Titles Contain Captain
print("The Total Number of Job Titles Contains Captains = ",df[df['JobTitle'].str.contains("Captain",case=False)].count()['JobTitle'])
# Out:
# The Total Number of Job Titles Contains Captains =  552

# %%
# Q11. Display All the Employee Names From Fire Department
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df['JobTitle']
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object

# %%
df['JobTitle'].str.contains("Fire",case=False)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: JobTitle, Length: 148654, dtype: bool

# %%
df[df['JobTitle'].str.contains("Fire",case=False)]
# Out:
#             Id        EmployeeName  \
# 4            5     PATRICK GARDNER
# 6            7           ALSON LEE
# 8            9      MICHAEL MORRIS
# 9           10  JOANNE HAYES-WHITE
# 10          11       ARTHUR KENNEY
# ...        ...                 ...
# 145956  145957    Kenneth C Farris
# 147556  147557       Edward A Dunn
# 148021  148022      Kari A Johnson
# 148209  148210        Sheryl K Lee
# 148554  148555     Lawrence F Gatt
#
#                                                 JobTitle    BasePay  \
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# 6                     BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01
# 8                     BATTALION CHIEF, (FIRE DEPARTMENT)  176932.64
# 9                 CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  285262.00
# 10      ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  194999.39
# ...                                                  ...        ...
# ...

# %%
df[df['JobTitle'].str.contains("Fire Department",case=False)]
# Out:
#             Id          EmployeeName  \
# 4            5       PATRICK GARDNER
# 6            7             ALSON LEE
# 8            9        MICHAEL MORRIS
# 9           10    JOANNE HAYES-WHITE
# 10          11         ARTHUR KENNEY
# ...        ...                   ...
# 32623    32624          JAMES BARDEN
# 36162    36163    Joanne Hayes-White
# 72926    72927  Joanne M Hayes-White
# 102303  102304        Robert E Evans
# 110535  110536  Joanne M Hayes-White
#
#                                                 JobTitle    BasePay  \
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# 6                     BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01
# 8                     BATTALION CHIEF, (FIRE DEPARTMENT)  176932.64
# 9                 CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  285262.00
# 10      ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  194999.39
# ...                                                  ...        ...
# ...

# %%
df[df['JobTitle'].str.contains("Fire Department",case=False)]["EmployeeName"]
# Out:
# 4              PATRICK GARDNER
# 6                    ALSON LEE
# 8               MICHAEL MORRIS
# 9           JOANNE HAYES-WHITE
# 10               ARTHUR KENNEY
#                   ...
# 32623             JAMES BARDEN
# 36162       Joanne Hayes-White
# 72926     Joanne M Hayes-White
# 102303          Robert E Evans
# 110535    Joanne M Hayes-White
# Name: EmployeeName, Length: 226, dtype: object

# %%
# Q11. Display All the Employee Names From Fire Department
df[df['JobTitle'].str.contains("Fire Department",case=False)]["EmployeeName"]
# Out:
# 4              PATRICK GARDNER
# 6                    ALSON LEE
# 8               MICHAEL MORRIS
# 9           JOANNE HAYES-WHITE
# 10               ARTHUR KENNEY
#                   ...
# 32623             JAMES BARDEN
# 36162       Joanne Hayes-White
# 72926     Joanne M Hayes-White
# 102303          Robert E Evans
# 110535    Joanne M Hayes-White
# Name: EmployeeName, Length: 226, dtype: object

# %%
# Q12.  Find Minimum, Maximum, and Average BasePay
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df['BasePay']
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
#             ...
# 148649         0.00
# 148650          NaN
# 148651          NaN
# 148652          NaN
# 148653         0.00
# Name: BasePay, Length: 148654, dtype: float64

# %%
df['BasePay'].dtype
# Out:
# dtype('float64')

# %%
df['BasePay'].agg(["max","min","mean"])
# Out:
# max     319275.01000
# min       -166.01000
# mean     66325.44884
# Name: BasePay, dtype: float64

# %%
df['BasePay'].describe()
# Out:
# count    148045.000000
# mean      66325.448840
# std       42764.635495
# min        -166.010000
# 25%       33588.200000
# 50%       65007.450000
# 75%       94691.050000
# max      319275.010000
# Name: BasePay, dtype: float64

# %%
#  Find Minimum, Maximum, and Average BasePay
print("Maximum BasePay = ",df['BasePay'].describe()['max'])
print("Minimum BasePay = ",df['BasePay'].describe()['min'])
print("Average BasePay = ",df['BasePay'].describe()['mean'])
# Out:
# Maximum BasePay =  319275.01
# Minimum BasePay =  -166.01
# Average BasePay =  66325.4488404877

# %%
# Q13. Replace 'Not Provided' in EmployeeName' Column to NaN
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650         Not provided
# 148651         Not provided
# 148652         Not provided
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %%
df['EmployeeName'].tail(10)
# Out:
# 148644        Randy D Winn
# 148645    Carolyn A Wilson
# 148646        Not provided
# 148647      Joann Anderson
# 148648         Leon Walker
# 148649       Roy I Tillery
# 148650        Not provided
# 148651        Not provided
# 148652        Not provided
# 148653           Joe Lopez
# Name: EmployeeName, dtype: object

# %%
df['EmployeeName']=="Not provided"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148649    False
# 148650     True
# 148651     True
# 148652     True
# 148653    False
# Name: EmployeeName, Length: 148654, dtype: bool

# %%
df[df['EmployeeName']=="Not provided"]
# Out:
#             Id  EmployeeName      JobTitle  BasePay  OvertimePay  OtherPay  \
# 148646  148647  Not provided  Not provided      NaN          NaN       NaN
# 148650  148651  Not provided  Not provided      NaN          NaN       NaN
# 148651  148652  Not provided  Not provided      NaN          NaN       NaN
# 148652  148653  Not provided  Not provided      NaN          NaN       NaN
#
#         Benefits  TotalPay  TotalPayBenefits  Year  Notes         Agency  \
# 148646       NaN       0.0               0.0  2014    NaN  San Francisco
# 148650       NaN       0.0               0.0  2014    NaN  San Francisco
# 148651       NaN       0.0               0.0  2014    NaN  San Francisco
# 148652       NaN       0.0               0.0  2014    NaN  San Francisco
#
#         Status
# 148646     NaN
# 148650     NaN
# 148651     NaN
# 148652     NaN

# %%
df['EmployeeName']=df['EmployeeName'].replace("Not provided",np.nan)

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651                NaN
# 148651  148652                NaN
# 148652  148653                NaN
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
df['EmployeeName'].tail(8)     # all 'Not Provided' Values are converted into NaN
# Out:
# 148646               NaN
# 148647    Joann Anderson
# 148648       Leon Walker
# 148649     Roy I Tillery
# 148650               NaN
# 148651               NaN
# 148652               NaN
# 148653         Joe Lopez
# Name: EmployeeName, dtype: object

# %%
# Q14 . Drop The Rows Having 5 Missing Values
df.isnull()
# Out:
#            Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 0       False         False     False    False        False     False
# 1       False         False     False    False        False     False
# 2       False         False     False    False        False     False
# 3       False         False     False    False        False     False
# 4       False         False     False    False        False     False
# ...       ...           ...       ...      ...          ...       ...
# 148649  False         False     False    False        False     False
# 148650  False          True     False     True         True      True
# 148651  False          True     False     True         True      True
# 148652  False          True     False     True         True      True
# 148653  False         False     False    False        False     False
#
#         Benefits  TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# ...

# %%
df.isnull().sum(axis=0)
# Out:
# Id                       0
# EmployeeName             4
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %%
df.isnull().sum(axis=1)
# Out:
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
#          ..
# 148649    2
# 148650    7
# 148651    7
# 148652    7
# 148653    2
# Length: 148654, dtype: int64

# %%
df.isnull().sum(axis=1)==5
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Length: 148654, dtype: bool

# %%
df[df.isnull().sum(axis=1)==5]
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Notes, Agency, Status]
# Index: []

# %%
df[df.isnull().sum(axis=1)==5].shape[0]
# Out:
# 0

# %%
len(df[df.isnull().sum(axis=1)==5])   # There are No Rows Which are contains 5 Non or Missing Values
# Out:
# 0

# %%
# Q15. Find Job Title of ALBERT PARDINI
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650                  NaN
# 148651                  NaN
# 148652                  NaN
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %%
df['EmployeeName']=="ALBERT PARDINI"
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: EmployeeName, Length: 148654, dtype: bool

# %%
df[df['EmployeeName']=="ALBERT PARDINI"]
# Out:
#    Id    EmployeeName                         JobTitle    BasePay  \
# 2   3  ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)  212739.13
#
#    OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 2    106088.18   16452.6       NaN  335279.91         335279.91  2011    NaN
#
#           Agency  Status
# 2  San Francisco     NaN

# %%
df[df['EmployeeName']=="ALBERT PARDINI"]['JobTitle']
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %%
df[df['EmployeeName']=="ALBERT PARDINI"]['JobTitle'][2]
# Out:
# 'CAPTAIN III (POLICE DEPARTMENT)'

# %%
print("Job Title of ALBERT PARDINI = ",df[df['EmployeeName']=="ALBERT PARDINI"]['JobTitle'][2])
# Out:
# Job Title of ALBERT PARDINI =  CAPTAIN III (POLICE DEPARTMENT)

# %%
# Q16. How Much ALBERT PARDINI Make (Include Benefits)?

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status              float64
# dtype: object

# %%
df["EmployeeName"]=="ALBERT PARDINI"
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: EmployeeName, Length: 148654, dtype: bool

# %%
df[df["EmployeeName"]=="ALBERT PARDINI"]
# Out:
#    Id    EmployeeName                         JobTitle    BasePay  \
# 2   3  ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)  212739.13
#
#    OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 2    106088.18   16452.6       NaN  335279.91         335279.91  2011    NaN
#
#           Agency  Status
# 2  San Francisco     NaN

# %%
df[df["EmployeeName"]=="ALBERT PARDINI"]["TotalPayBenefits"]
# Out:
# 2    335279.91
# Name: TotalPayBenefits, dtype: float64

# %%
df[df["EmployeeName"]=="ALBERT PARDINI"]["TotalPayBenefits"][2]
# Out:
# 335279.91

# %%
print("The Total Benefits of 'ALBERT PARDINI' is =",df[df["EmployeeName"]=="ALBERT PARDINI"]["TotalPayBenefits"][2])
# Out:
# The Total Benefits of 'ALBERT PARDINI' is = 335279.91

# %%
# 17. Display Name of The Person Having The Highest BasePay
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df["BasePay"]
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
#             ...
# 148649         0.00
# 148650          NaN
# 148651          NaN
# 148652          NaN
# 148653         0.00
# Name: BasePay, Length: 148654, dtype: float64

# %%
df['BasePay'].max()
# Out:
# 319275.01

# %%
df['BasePay'].max()==df['BasePay']
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: BasePay, Length: 148654, dtype: bool

# %%
df[df['BasePay'].max()==df['BasePay']]
# Out:
#           Id    EmployeeName         JobTitle    BasePay  OvertimePay  \
# 72925  72926  Gregory P Suhr  Chief of Police  319275.01          0.0
#
#        OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 72925  20007.06  86533.21  339282.07         425815.28  2013    NaN
#
#               Agency  Status
# 72925  San Francisco     NaN

# %%
df[df['BasePay'].max()==df['BasePay']]['EmployeeName']
# Out:
# 72925    Gregory P Suhr
# Name: EmployeeName, dtype: object

# %%
df[df['BasePay'].max()==df['BasePay']]['EmployeeName'][72925]
# Out:
# 'Gregory P Suhr'

# %%
print("Employee Name which Contains Highest Pay = ",df[df['BasePay'].max()==df['BasePay']]['EmployeeName'][72925])
# Out:
# Employee Name which Contains Highest Pay =  Gregory P Suhr

# %%
# 18.Find Average BasePay of All Employee Per Year 
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df.groupby('Year')

# %%
df.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
df.groupby('Year')['BasePay'].agg(['mean'])
# Out:
#               mean
# Year
# 2011  63595.956517
# 2012  65436.406857
# 2013  69630.030216
# 2014  66564.421924

# %%
# 19. Find Average BasePay of All Employee Per JobTitle
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df['JobTitle']
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object

# %%
df.groupby('JobTitle')['BasePay'].mean()
# Out:
# JobTitle
# ACCOUNT CLERK                                     43300.806506
# ACCOUNTANT                                        46643.172000
# ACCOUNTANT INTERN                                 28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
# ACUPUNCTURIST                                     66374.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             47664.773077
# X-Ray Laboratory Aide                             46086.387100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.910000
# Youth Comm Advisor                                39077.957500
# ZOO CURATOR                                       43148.000000
# Name: BasePay, Length: 2159, dtype: float64

# %%
df.groupby('JobTitle')['BasePay'].agg(['mean'])
# Out:
#                                                         mean
# JobTitle
# ACCOUNT CLERK                                   43300.806506
# ACCOUNTANT                                      46643.172000
# ACCOUNTANT INTERN                               28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                     62290.780000
# ACUPUNCTURIST                                   66374.400000
# ...                                                      ...
# X-RAY LABORATORY AIDE                           47664.773077
# X-Ray Laboratory Aide                           46086.387100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS  52609.910000
# Youth Comm Advisor                              39077.957500
# ZOO CURATOR                                     43148.000000
#
# [2159 rows x 1 columns]

# %%
# For Verification --> It is Correct
df[df['JobTitle']=="ACCOUNTANT"]['BasePay'].mean().sum()
# Out:
# 46643.172

# %%
# 20. Find Average BasePay of Employee Having Job Title ACCOUNTANT

# %%
df['JobTitle']
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object

# %%
df['JobTitle']=="ACCOUNTANT"
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: JobTitle, Length: 148654, dtype: bool

# %%
df[df['JobTitle']=="ACCOUNTANT"]
# Out:
#           Id      EmployeeName    JobTitle   BasePay  OvertimePay  OtherPay  \
# 19263  19264  CARLITO NEPACENA  ACCOUNTANT  65392.01          0.0      0.00
# 19324  19325     ROSALINDA TAN  ACCOUNTANT  65225.31          0.0      0.00
# 20992  20993   NELSON ALVARADO  ACCOUNTANT  60076.24          0.0      0.00
# 25927  25928   JEANETTE COOPER  ACCOUNTANT  42522.30          0.0   2782.08
# 35285  35286     CESAR PALARCA  ACCOUNTANT      0.00          0.0   1148.40
#
#        Benefits  TotalPay  TotalPayBenefits  Year  Notes         Agency  \
# 19263       NaN  65392.01          65392.01  2011    NaN  San Francisco
# 19324       NaN  65225.31          65225.31  2011    NaN  San Francisco
# 20992       NaN  60076.24          60076.24  2011    NaN  San Francisco
# 25927       NaN  45304.38          45304.38  2011    NaN  San Francisco
# 35285       NaN   1148.40           1148.40  2011    NaN  San Francisco
#
#        Status
# 19263     NaN
# 19324     NaN
# 20992     NaN
# ...

# %%
df[df['JobTitle']=="ACCOUNTANT"]['BasePay'].mean()
# Out:
# 46643.172

# %%
# 21. Find Top 5 Most Common Jobs
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df['JobTitle']
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object

# %%
df['JobTitle'].value_counts()
# Out:
# JobTitle
# Transit Operator                                  7036
# Special Nurse                                     4389
# Registered Nurse                                  3736
# Public Svc Aide-Public Works                      2518
# Police Officer 3                                  2421
#                                                   ...
# CHIEF HOUSING INSPECTOR                              1
# TRAFFIC SIGNAL OPERATOR                              1
# COURT COMPUTER FACILITIES COORDINATOR                1
# AUTOMOTIVE BODY AND FENDER WORKER SUPERVISOR I       1
# VICTIM & WITNESS TECHNICIAN                          1
# Name: count, Length: 2159, dtype: int64

# %%
df['JobTitle'].value_counts().sort_values().tail(5)[::-1]
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %%
df['JobTitle'].value_counts().head()
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64
